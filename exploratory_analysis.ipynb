# %%
import os
import os.path
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('W:\Thesis\Model\Data\data.xlsx')

# %%
list(data)
# Out:
# ['AnonID',
#  'Visit ID',
#  'IsCVHData',
#  'SiteCode',
#  'SiteDescription',
#  'VisitTypeCode',
#  'VisitTypeDescription',
#  'InstitutionCode',
#  'Institution',
#  'IsValidHealthCareNumber',
#  'HCNProvinceCode',
#  'HealthCareProvinceCode',
#  'ResponsibilityForPaymentCode',
#  'ResponsibilityForPayment',
#  'GenderCode',
#  'Gender',
#  'AccessToPrimaryHealthcareProviderCode',
#  'AccessToPrimaryHealthcareProviderDescription',
#  'AmbulanceArrivalDate',
#  'AmbulanceTransferDate',
#  'ArrivalDate',
#  'TriageDate',
#  'RegistrationDateKey',
#  'RegistrationDate',
#  'AssessmentDate',
#  'IsCDUCase',
#  'DecisionToAdmitDate',
#  'ConsultRequestDate',
#  'ConsultArrivalDate',
#  'VisitDispositionDate',
#  'DateLeftER',
#  'MISFunctionalCentreCode',
#  'MISFunctionalCentreDescription',
#  'TriageLevelCode',
#  'TriageLevelDescription',
#  'AdmitAmbulanceCode',
#  'AdmitAmbulanceDescription',
#  'GlasgowComaScaleDescription',
#  'DischargeDispositionCode',
# ...

# %%
data.head(2)
# Out:
#                AnonID  Visit ID  IsCVHData SiteCode SiteDescription  \
# 0  ADK7911108591RX492   6557771          0        Q  Queensway Site
# 1  ACZ7801200123TH528   6580712          0        Q  Queensway Site
#
#   VisitTypeCode VisitTypeDescription  InstitutionCode  \
# 0            ER         ER/UCC Visit            54759
# 1            ER         ER/UCC Visit            54759
#
#                                 Institution IsValidHealthCareNumber  \
# 0  Trillium Health Partners NACRS - WT Site                       Y
# 1  Trillium Health Partners NACRS - WT Site                       Y
#
#       ...      ExamMonth                Shift  is NigthShift 12 - 6:59  \
# 0     ...       201502.0    8:00 am - 4:59 PM                        N
# 1     ...       201503.0  5:00 PM to 11:59 PM                        N
#
#   DayOfWeek is NigthShift 1 - 6:59 WeekendOrWeekDay  \
# 0  Thursday                      N          Weekday
# 1   Tuesday                      N          Weekday
#
# ...

# %%
u_data = data[['SiteCode','RegistrationDate','PatientType','ExamFinishDateTime','ExamMonth','DayOfWeek','WeekendOrWeekDay']]

# %%
e_data = u_data[u_data['PatientType']=='ED']

# %%
e_data.head()
# Out:
#   SiteCode    RegistrationDate PatientType  ExamFinishDateTime  ExamMonth  \
# 2        M 2014-04-01 11:48:00          ED 2015-02-12 09:20:00   201502.0
# 3        M 2014-05-25 14:18:00          ED 2015-05-14 13:08:00   201505.0
# 5        M 2014-06-20 06:56:00          ED 2015-02-26 13:41:00   201502.0
# 6        M 2014-06-20 06:56:00          ED 2015-02-26 13:41:00   201502.0
# 7        C 2014-06-20 23:24:00          ED 2015-05-12 10:26:00   201504.0
#
#   DayOfWeek WeekendOrWeekDay
# 2  Thursday          Weekday
# 3  Thursday          Weekday
# 5  Thursday          Weekday
# 6  Thursday          Weekday
# 7  Thursday          Weekday
